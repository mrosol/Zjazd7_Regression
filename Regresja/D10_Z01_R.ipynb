# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(0.5*x**2-2)*(x-2)+5) # Zmiana na 0.5*x**2 !!!
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca() # get current axes
axes.set_xlim([0,3])
axes.set_ylim([0,18])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszą regresję.

# %%
np.random.seed(10)
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,18])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None) # least-squares solution to a linear matrix equation

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,20])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
p2
# Out:
# (array([ 4.17957066, -0.17697175,  0.80048074]),
#  array([329.33144245]),
#  3,
#  array([41.75880945,  7.26448546,  1.81587665]))

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,20])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,20])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

# %%
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,20])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)

# %%
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,20])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
M6 = np.vstack( (np.ones_like(x), x, x**2, np.exp(x), np.log(x+1)) ).T
p6 = np.linalg.lstsq(M6, y, rcond=None)

# %%
f_lr_6 = lambda x: p6[0][4]*np.log(x+1) + p6[0][3]*np.exp(x) + p6[0][2]*pow(x,2) + p6[0][1] * x + p6[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_6(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,20])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
M55 = np.vstack( (np.ones_like(x), x, x**3, x**4, x**5) ).T
p55 = np.linalg.lstsq(M55, y, rcond=None)

# %%
f_lr_55 = lambda x: p55[0][4]*pow(x,5) + p55[0][3]*pow(x,4) + p55[0][2]*pow(x,3) + p55[0][1] * x + p55[0][0]

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_1 = f_lr_1(x_tr)
y_f_lr_2 = f_lr_2(x_tr)
y_f_lr_3 = f_lr_3(x_tr)
y_f_lr_4 = f_lr_4(x_tr)
y_f_lr_5 = f_lr_5(x_tr)
y_f_lr_6 = f_lr_6(x_tr)
y_f_lr_55 = f_lr_55(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,20])
plt.plot(x_f_lr, y_f_lr_1, 'r', label= "1");
plt.plot(x_f_lr, y_f_lr_2, 'g', label= "2");
plt.plot(x_f_lr, y_f_lr_3, 'b', label= "3");
plt.plot(x_f_lr, y_f_lr_4, 'c', label= "4");
plt.plot(x_f_lr, y_f_lr_5, 'm', label= "5");
plt.plot(x_f_lr, y_f_lr_6, 'y', alpha = 0.5, label= "6");
plt.plot(x, y, 'ok', ms=10, alpha=0.3);
plt.legend()
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()
Res6 = sm.OLS(y, M6).fit()

print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.470
# Dependent Variable: y                AIC:                415.2971
# Date:               2020-11-22 11:18 BIC:                420.5075
# No. Observations:   100              Log-Likelihood:     -205.65
# Df Model:           1                F-statistic:        88.70
# Df Residuals:       98               Prob (F-statistic): 2.22e-15
# R-squared:          0.475            Scale:              3.6521
# --------------------------------------------------------------------
#           Coef.     Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     2.9869      0.3877    7.7044    0.0000    2.2175    3.7562
# x1        2.1818      0.2317    9.4181    0.0000    1.7221    2.6415
# -----------------------------------------------------------------
# Omnibus:              22.265       Durbin-Watson:          1.818
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       31.869
# Skew:                 1.040        Prob(JB):               0.000
# Kurtosis:             4.822        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()
M5_5 = np.vstack( (np.ones_like(x_tr), x_tr, x_tr**2, x_tr**3, x_tr**4, x_tr**5) ).T
y1 = Res5.predict(M5_5)
plt.figure(figsize=(6,6))
plt.plot(x_tr,y1)
plt.plot(x,y,'ko')

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.470
# Dependent Variable: y                AIC:                415.2971
# Date:               2020-11-22 11:18 BIC:                420.5075
# No. Observations:   100              Log-Likelihood:     -205.65
# Df Model:           1                F-statistic:        88.70
# Df Residuals:       98               Prob (F-statistic): 2.22e-15
# R-squared:          0.475            Scale:              3.6521
# --------------------------------------------------------------------
#           Coef.     Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     2.9869      0.3877    7.7044    0.0000    2.2175    3.7562
# x1        2.1818      0.2317    9.4181    0.0000    1.7221    2.6415
# -----------------------------------------------------------------
# Omnibus:              22.265       Durbin-Watson:          1.818
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       31.869
# Skew:                 1.040        Prob(JB):               0.000
# Kurtosis:             4.822        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.507
# Dependent Variable: y                AIC:                408.9772
# Date:               2020-11-22 11:18 BIC:                416.7927
# No. Observations:   100              Log-Likelihood:     -201.49
# Df Model:           2                F-statistic:        51.91
# Df Residuals:       97               Prob (F-statistic): 4.69e-16
# R-squared:          0.517            Scale:              3.3952
# -------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025   0.975]
# -------------------------------------------------------------------
# const       4.1796     0.5557    7.5218   0.0000    3.0767   5.2824
# x1         -0.1770     0.8432   -0.2099   0.8342   -1.8505   1.4966
# x2          0.8005     0.2759    2.9010   0.0046    0.2528   1.3481
# -----------------------------------------------------------------
# Omnibus:              4.301        Durbin-Watson:           1.929
# Prob(Omnibus):        0.116        Jarque-Bera (JB):        4.019
# Skew:                 0.491        Prob(JB):                0.134
# Kurtosis:             3.022        Condition No.:           23
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.975
# Dependent Variable: y                AIC:                112.7962
# Date:               2020-11-22 11:18 BIC:                123.2169
# No. Observations:   100              Log-Likelihood:     -52.398
# Df Model:           3                F-statistic:        1275.
# Df Residuals:       96               Prob (F-statistic): 3.64e-77
# R-squared:          0.976            Scale:              0.17393
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -0.1119    0.1614   -0.6933  0.4898   -0.4324    0.2085
# x1         17.9206    0.4676   38.3255  0.0000   16.9924   18.8487
# x2        -14.7460    0.3720  -39.6425  0.0000  -15.4844  -14.0076
# x3          3.5311    0.0833   42.3964  0.0000    3.3658    3.6964
# -----------------------------------------------------------------
# Omnibus:              4.065        Durbin-Watson:           1.740
# Prob(Omnibus):        0.131        Jarque-Bera (JB):        2.206
# Skew:                 0.052        Prob(JB):                0.332
# Kurtosis:             2.280        Condition No.:           150
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.994
# Dependent Variable: y                AIC:                -35.0305
# Date:               2020-11-22 11:18 BIC:                -22.0046
# No. Observations:   100              Log-Likelihood:     22.515
# Df Model:           4                F-statistic:        4315.
# Df Residuals:       95               Prob (F-statistic): 1.78e-106
# R-squared:          0.995            Scale:              0.039286
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const       0.9212     0.0955    9.6458   0.0000    0.7316    1.1108
# x1         10.5156     0.4643   22.6502   0.0000    9.5939   11.4372
# x2         -3.5120     0.6432   -5.4606   0.0000   -4.7889   -2.2352
# x3         -2.3395     0.3256   -7.1859   0.0000   -2.9859   -1.6932
# x4          0.9859     0.0543   18.1665   0.0000    0.8782    1.0937
# ------------------------------------------------------------------
# Omnibus:              2.768         Durbin-Watson:           1.895
# Prob(Omnibus):        0.251         Jarque-Bera (JB):        2.195
# Skew:                 -0.341        Prob(JB):                0.334
# Kurtosis:             3.246         Condition No.:           1141
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.994
# Dependent Variable: y                AIC:                -33.7549
# Date:               2020-11-22 11:18 BIC:                -18.1239
# No. Observations:   100              Log-Likelihood:     22.877
# Df Model:           5                F-statistic:        3441.
# Df Residuals:       94               Prob (F-statistic): 8.89e-105
# R-squared:          0.995            Scale:              0.039417
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const       0.9818     0.1205    8.1492   0.0000    0.7426    1.2210
# x1          9.9060     0.8718   11.3625   0.0000    8.1749   11.6370
# x2         -2.1284     1.7934   -1.1868   0.2383   -5.6893    1.4325
# x3         -3.5479     1.4977   -2.3689   0.0199   -6.5216   -0.5742
# x4          1.4345     0.5453    2.6306   0.0100    0.3518    2.5173
# x5         -0.0595     0.0719   -0.8267   0.4105   -0.2023    0.0834
# ------------------------------------------------------------------
# Omnibus:              2.727         Durbin-Watson:           1.861
# Prob(Omnibus):        0.256         Jarque-Bera (JB):        2.178
# Skew:                 -0.344        Prob(JB):                0.337
# Kurtosis:             3.220         Condition No.:           9051
# ==================================================================
# * The condition number is large (9e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()
Res3F = smf.ols('y ~ x+I(x**2)+I(x**3)', df).fit()
Res4F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()
print(Res5F.summary())
df1 = pd.DataFrame({'x':x_tr})
y_pred = Res4F.predict(df1['x'])
plt.plot(x_tr,y_pred,'o')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     3441.
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):          8.89e-105
# Time:                        11:21:15   Log-Likelihood:                 22.877
# No. Observations:                 100   AIC:                            -33.75
# Df Residuals:                      94   BIC:                            -18.12
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9818      0.120      8.149      0.000       0.743       1.221
# x              9.9060      0.872     11.362      0.000       8.175      11.637
# I(x ** 2)     -2.1284      1.793     -1.187      0.238      -5.689       1.432
# I(x ** 3)     -3.5479      1.498     -2.369      0.020      -6.522      -0.574
# I(x ** 4)      1.4345      0.545      2.631      0.010       0.352       2.517
# I(x ** 5)     -0.0595      0.072     -0.827      0.411      -0.202       0.083
# ==============================================================================
# Omnibus:                        2.727   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.256   Jarque-Bera (JB):                2.178
# Skew:                          -0.344   Prob(JB):                        0.337
# Kurtosis:                       3.220   Cond. No.                     9.05e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.491
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     94.68
# Date:                Thu, 19 Nov 2020   Prob (F-statistic):           4.66e-16
# Time:                        12:19:31   Log-Likelihood:                -306.42
# No. Observations:                 100   AIC:                             616.8
# Df Residuals:                      98   BIC:                             622.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0361      1.062     -0.976      0.332      -3.144       1.071
# x              6.1748      0.635      9.730      0.000       4.916       7.434
# ==============================================================================
# Omnibus:                       37.377   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.497
# Skew:                           1.454   Prob(JB):                     5.46e-18
# Kurtosis:                       6.258   Cond. No.                         4.38
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.491
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     94.68
# Date:                Thu, 19 Nov 2020   Prob (F-statistic):           4.66e-16
# Time:                        12:19:31   Log-Likelihood:                -306.42
# No. Observations:                 100   AIC:                             616.8
# Df Residuals:                      98   BIC:                             622.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0361      1.062     -0.976      0.332      -3.144       1.071
# x              6.1748      0.635      9.730      0.000       4.916       7.434
# ==============================================================================
# Omnibus:                       37.377   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.497
# Skew:                           1.454   Prob(JB):                     5.46e-18
# Kurtosis:                       6.258   Cond. No.                         4.38
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     2967.
# Date:                Thu, 19 Nov 2020   Prob (F-statistic):           1.75e-94
# Time:                        12:19:31   Log-Likelihood:                -113.20
# No. Observations:                 100   AIC:                             234.4
# Df Residuals:                      96   BIC:                             244.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.1598      0.297     -3.911      0.000      -1.748      -0.571
# x             25.4311      0.859     29.610      0.000      23.726      27.136
# I(x ** 2)    -25.1401      0.683    -36.795      0.000     -26.496     -23.784
# I(x ** 3)      6.9854      0.153     45.661      0.000       6.682       7.289
# ==============================================================================
# Omnibus:                        4.037   Durbin-Watson:                   1.667
# Prob(Omnibus):                  0.133   Jarque-Bera (JB):                2.676
# Skew:                           0.219   Prob(JB):                        0.262
# Kurtosis:                       2.329   Cond. No.                         150.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.358e+04
# Date:                Thu, 19 Nov 2020   Prob (F-statistic):          1.06e-148
# Time:                        12:19:31   Log-Likelihood:                 22.515
# No. Observations:                 100   AIC:                            -35.03
# Df Residuals:                      95   BIC:                            -22.00
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9212      0.096      9.646      0.000       0.732       1.111
# x             10.5156      0.464     22.650      0.000       9.594      11.437
# I(x ** 2)     -2.5120      0.643     -3.906      0.000      -3.789      -1.235
# I(x ** 3)     -4.8395      0.326    -14.865      0.000      -5.486      -4.193
# I(x ** 4)      1.9859      0.054     36.592      0.000       1.878       2.094
# ==============================================================================
# Omnibus:                        2.768   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.251   Jarque-Bera (JB):                2.195
# Skew:                          -0.341   Prob(JB):                        0.334
# Kurtosis:                       3.246   Cond. No.                     1.14e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.14e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.677e+04
# Date:                Thu, 19 Nov 2020   Prob (F-statistic):          1.48e-146
# Time:                        12:19:31   Log-Likelihood:                 22.877
# No. Observations:                 100   AIC:                            -33.75
# Df Residuals:                      94   BIC:                            -18.12
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9818      0.120      8.149      0.000       0.743       1.221
# x              9.9060      0.872     11.362      0.000       8.175      11.637
# I(x ** 2)     -1.1284      1.793     -0.629      0.531      -4.689       2.432
# I(x ** 3)     -6.0479      1.498     -4.038      0.000      -9.022      -3.074
# I(x ** 4)      2.4345      0.545      4.464      0.000       1.352       3.517
# I(x ** 5)     -0.0595      0.072     -0.827      0.411      -0.202       0.083
# ==============================================================================
# Omnibus:                        2.727   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.256   Jarque-Bera (JB):                2.178
# Skew:                          -0.344   Prob(JB):                        0.337
# Kurtosis:                       3.220   Cond. No.                     9.05e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
M6 = np.vstack( (np.ones_like(x), x, x**2, np.exp(x)) ).T
p6 = np.linalg.lstsq(M6, y, rcond=None)

# %%
f_lr_6 = lambda x: p6[0][3]* np.exp(x) + p6[0][2]*pow(x,2) + p6[0][1]*x + p6[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_6(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,20])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
Res6 = sm.OLS(y, M6).fit()
print(Res6.summary2())
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                5.4630
# Date:               2020-11-19 12:20 BIC:                15.8837
# No. Observations:   100              Log-Likelihood:     1.2685
# Df Model:           3                F-statistic:        2.957e+04
# Df Residuals:       96               Prob (F-statistic): 3.32e-142
# R-squared:          0.999            Scale:              0.059462
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# const      -8.0732    0.1284   -62.8881  0.0000   -8.3280   -7.8184
# x1          6.9413    0.1626    42.6892  0.0000    6.6186    7.2641
# x2        -15.7265    0.1503  -104.6368  0.0000  -16.0248  -15.4282
# x3          8.4127    0.0575   146.3816  0.0000    8.2986    8.5268
# ------------------------------------------------------------------
# Omnibus:              1.398         Durbin-Watson:           2.139
# Prob(Omnibus):        0.497         Jarque-Bera (JB):        1.171
# Skew:                 -0.265        Prob(JB):                0.557
# Kurtosis:             3.003         Condition No.:           90
# ==================================================================

# %%
Res6 = sm.OLS(y, M6).fit()
print(Res6.summary2())
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                5.4630
# Date:               2020-10-11 11:38 BIC:                15.8837
# No. Observations:   100              Log-Likelihood:     1.2685
# Df Model:           3                F-statistic:        2.957e+04
# Df Residuals:       96               Prob (F-statistic): 3.32e-142
# R-squared:          0.999            Scale:              0.059462
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# const      -8.0732    0.1284   -62.8881  0.0000   -8.3280   -7.8184
# x1          6.9413    0.1626    42.6892  0.0000    6.6186    7.2641
# x2        -15.7265    0.1503  -104.6368  0.0000  -16.0248  -15.4282
# x3          8.4127    0.0575   146.3816  0.0000    8.2986    8.5268
# ------------------------------------------------------------------
# Omnibus:              1.398         Durbin-Watson:           2.139
# Prob(Omnibus):        0.497         Jarque-Bera (JB):        1.171
# Skew:                 -0.265        Prob(JB):                0.557
# Kurtosis:             3.003         Condition No.:           90
# ==================================================================

# %%
# Out:
# (array([ 0.92122997, 10.51557553, -2.5120437 , -4.83953762,  1.98594642]),
#  array([3.73216361]),
#  5,
#  array([2.64788012e+02, 1.89534709e+01, 5.48830595e+00, 1.57656972e+00,
#         2.31977728e-01]))

# %% [markdown]
# # Graficzna ewaluacja modeli

# %%
y_f_lr_1 = f_lr_1(x)
y_f_lr_2 = f_lr_2(x)
y_f_lr_3 = f_lr_3(x)
y_f_lr_4 = f_lr_4(x)
y_f_lr_5 = f_lr_5(x)
y_f_lr_6 = f_lr_6(x)

# %%
fig, ax = plt.subplots(2,3,figsize=(15,15))
ax[0][0].plot(y, y_f_lr_1, 'o', label= "1")
ax[0][0].plot(np.linspace(0,20), np.linspace(0,20), 'k')
ax[0][0].set_xlim([0,20])
ax[0][0].set_ylim([0,20])
ax[0][0].set_xlabel('y')
ax[0][0].set_ylabel('y_hat')

ax[0][1].plot(y, y_f_lr_2, 'o', label= "2")
ax[0][1].plot(np.linspace(0,20), np.linspace(0,20), 'k')
ax[0][1].set_xlim([0,20])
ax[0][1].set_ylim([0,20])
ax[0][0].set_xlabel('y')
ax[0][0].set_ylabel('y_hat')

#ax[0][2].plot(y, y_f_lr_3, 'o', label= "3")

#ax[1][0].plot(y, y_f_lr_4, 'o', label= "4")

#ax[1][1].plot(y, y_f_lr_5, 'o', label= "5")

#ax[1][2].plot(y, y_f_lr_6, 'o', label= "6")
ys = [y_f_lr_1,y_f_lr_2,y_f_lr_3,y_f_lr_4,y_f_lr_5,y_f_lr_6]
k =0
for i in range(2):
    for j in range(3):
        ax[i][j].plot(y,ys[k],'o')
        ax[i][j].plot(np.linspace(0,20), np.linspace(0,20), 'k')
        ax[i][j].set_xlim([0,20])
        ax[i][j].set_ylim([0,20])
        ax[i][j].set_xlabel('y')
        ax[i][j].set_ylabel('y_hat')
        k+=1

# %%
fig, ax = plt.subplots(2,3,figsize=(15,15))
ax[0][0].plot(y_f_lr_1, y-y_f_lr_1, 'o', label= "1")
ax[0][0].plot(np.linspace(-1,20), np.zeros([50,1]), 'k')
ax[0][0].set_xlim([-1,20])
ax[0][0].set_ylim([-20,20])
ax[0][0].set_xlabel('wartości predykowane')
ax[0][0].set_ylabel('residua')

ax[0][1].plot(y_f_lr_2, y - y_f_lr_2, 'o', label= "2")
ax[0][1].plot(np.linspace(-1,20), np.zeros([50,1]), 'k')
ax[0][1].set_xlim([-1,20])
ax[0][1].set_ylim([-20,20])
ax[0][0].set_xlabel('wartości predykowane')
ax[0][0].set_ylabel('residua')


ys = [y_f_lr_1,y_f_lr_2,y_f_lr_3,y_f_lr_4,y_f_lr_5,y_f_lr_6]
k =0
for i in range(2):
    for j in range(3):
        ax[i][j].plot(ys[k], y-ys[k], 'o')
        ax[i][j].plot(np.linspace(-1,20), np.zeros([50,1]), 'k')
        ax[i][j].set_xlim([-1,20])
        ax[i][j].set_ylim([-20,20])
        ax[i][j].set_xlabel('wartości predykowane')
        ax[i][j].set_ylabel('residua')
        k+=1
